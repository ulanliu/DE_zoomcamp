# %%
import pandas as pd
import requests
from datetime import date

# %%
binance_prefix = 'https://api1.binance.com'
exchange_info = '/api/v3/exchangeInfo'
symbol_price_ticker = '/api/v3/ticker/price'
ticker_price_change_statistics = '/api/v3/ticker/24hr'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f5/c2cthfkx51zdsrmg13dv_kwh0000gn/T/ipykernel_17993/4276247179.py in <module>
#       1 binance_prefix = 'https://api1.binance.com'
#       2 exchange_info = '/api/v3/exchangeInfo'
# ----> 3 symbol_price_ticker = f'/api/v3/{ticker}/price'
#       4 ticker_price_change_statistics = '/api/v3/ticker/24hr'
#
# NameError: name 'ticker' is not defined

# %%
r = requests.get(binance_prefix+exchange_info)

# %%
content = r.json()

# %%
content
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1678777931307,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 1200},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 6100}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
# ...

# %%
content['symbols'][0]['symbol']
# Out:
# 'ETHBTC'

# %%
ticker_list = []

for i in range(len(content['symbols'])):
    ticker_list.append(content['symbols'][i]['symbol'])

# %%
len(ticker_list)
# Out:
# 2161

# %%
ticker_list[2]
# Out:
# 'BNBBTC'

# %%
symbols = '["KEYUSDT","BNBUSDT","ADAUSDT"]'
params = {'symbols': symbols}

# %%
r_1 = requests.get(binance_prefix+'/api/v3/ticker/price', params=params)

# %%
r_1.json()
# Out:
# [{'symbol': 'BNBUSDT', 'price': '304.50000000'},
#  {'symbol': 'ADAUSDT', 'price': '0.34100000'},
#  {'symbol': 'KEYUSDT', 'price': '0.01083500'}]

# %%
r_1.status_code
# Out:
# 200

# %%
requests.get(binance_prefix+'/api/v3/ticker/price', params=params).json()
# Out:
# [{'symbol': 'BNBUSDT', 'price': '302.50000000'},
#  {'symbol': 'ADAUSDT', 'price': '0.33820000'},
#  {'symbol': 'KEYUSDT', 'price': '0.01057000'}]

# %%
requests.get(binance_prefix+'/api/v3/ticker/price', params= {'symbol': 'BTCUSDT'}).json()
# Out:
# {'symbol': 'BTCUSDT', 'price': '24135.90000000'}

# %%
requests.get(binance_prefix+'/api/v3/ticker/price', params= {'symbol': 'BTCUSDT'}).json()
# Out:
# {'symbol': 'BTCUSDT', 'price': '24138.37000000'}

# %%
requests.get(binance_prefix+'/api/v3/ticker/24hr', params= {'symbol': 'BTCUSDT'}).json()
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '1796.38000000',
#  'priceChangePercent': '8.014',
#  'weightedAvgPrice': '23519.63541392',
#  'prevClosePrice': '22414.33000000',
#  'lastPrice': '24210.71000000',
#  'lastQty': '0.01180000',
#  'bidPrice': '24210.74000000',
#  'bidQty': '0.23713000',
#  'askPrice': '24212.68000000',
#  'askQty': '0.05065000',
#  'openPrice': '22414.33000000',
#  'highPrice': '24820.00000000',
#  'lowPrice': '21813.88000000',
#  'volume': '654864.38927000',
#  'quoteVolume': '15402171681.19040290',
#  'openTime': 1678695422781,
#  'closeTime': 1678781822781,
#  'firstId': 2944442845,
#  'lastId': 2958942881,
#  'count': 14500037}

# %%
requests.get(binance_prefix+'/api/v3/ticker/24hr', params= {'symbol': 'BTCUSDT'}).json()
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '1803.09000000',
#  'priceChangePercent': '8.050',
#  'weightedAvgPrice': '23520.55735511',
#  'prevClosePrice': '22397.83000000',
#  'lastPrice': '24200.94000000',
#  'lastQty': '0.00400000',
#  'bidPrice': '24200.22000000',
#  'bidQty': '0.07000000',
#  'askPrice': '24201.26000000',
#  'askQty': '0.75522000',
#  'openPrice': '22397.85000000',
#  'highPrice': '24820.00000000',
#  'lowPrice': '21813.88000000',
#  'volume': '654675.04841000',
#  'quoteVolume': '15398322025.08584670',
#  'openTime': 1678695467924,
#  'closeTime': 1678781867924,
#  'firstId': 2944450046,
#  'lastId': 2958948435,
#  'count': 14498390}

# %%
url = 'https://raw.githubusercontent.com/owid/monkeypox/main/owid-monkeypox-data.csv'

# %%
df = pd.read_csv('prefect/data/monkeypox_20230316.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27269 entries, 0 to 27268
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   location                         27269 non-null  object
#  1   iso_code                         27269 non-null  object
#  2   date                             27269 non-null  object
#  3   total_cases                      27269 non-null  float64
#  4   total_deaths                     27269 non-null  float64
#  5   new_cases                        27269 non-null  float64
#  6   new_deaths                       27269 non-null  float64
#  7   new_cases_smoothed               27269 non-null  float64
#  8   new_deaths_smoothed              27269 non-null  float64
#  9   new_cases_per_million            27269 non-null  float64
#  10  total_cases_per_million          27269 non-null  float64
# ...

# %%
df.head()
# Out:
#   location  iso_code        date  total_cases  total_deaths  new_cases  \
# 0   Africa  OWID_AFR  2022-05-01         27.0           2.0        0.0
# 1   Africa  OWID_AFR  2022-05-02         27.0           2.0        0.0
# 2   Africa  OWID_AFR  2022-05-03         27.0           2.0        0.0
# 3   Africa  OWID_AFR  2022-05-04         27.0           2.0        0.0
# 4   Africa  OWID_AFR  2022-05-05         27.0           2.0        0.0
#
#    new_deaths  new_cases_smoothed  new_deaths_smoothed  new_cases_per_million  \
# 0         0.0                0.29                  0.0                    0.0
# 1         0.0                0.29                  0.0                    0.0
# 2         0.0                0.29                  0.0                    0.0
# 3         0.0                0.29                  0.0                    0.0
# 4         0.0                0.29                  0.0                    0.0
#
#    total_cases_per_million  new_cases_smoothed_per_million  \
# ...

# %%
df.iso_code.unique()
# Out:
# array(['OWID_AFR', 'AND', 'ARG', 'ABW', 'OWID_ASI', 'AUS', 'AUT', 'BHS',
#        'BHR', 'BRB', 'BEL', 'BEN', 'BMU', 'BOL', 'BIH', 'BRA', 'BGR',
#        'CMR', 'CAN', 'CAF', 'CHL', 'CHN', 'COL', 'COG', 'CRI', 'HRV',
#        'CUB', 'CUW', 'CYP', 'CZE', 'COD', 'DNK', 'DOM', 'ECU', 'EGY',
#        'SLV', 'EST', 'OWID_EUR', 'FIN', 'FRA', 'GEO', 'DEU', 'GHA', 'GIB',
#        'GRC', 'GRL', 'GLP', 'GUM', 'GTM', 'GUY', 'HND', 'HUN', 'ISL',
#        'IND', 'IDN', 'IRN', 'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR',
#        'LVA', 'LBN', 'LBR', 'LTU', 'LUX', 'MLT', 'MTQ', 'MEX', 'MDA',
#        'MCO', 'MNE', 'MAR', 'MOZ', 'NLD', 'NCL', 'NZL', 'NGA', 'OWID_NAM',
#        'NOR', 'OWID_OCE', 'PAN', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'PRI',
#        'QAT', 'ROU', 'RUS', 'MAF', 'SMR', 'SAU', 'SRB', 'SGP', 'SVK',
#        'SVN', 'ZAF', 'OWID_SAM', 'KOR', 'ESP', 'LKA', 'SDN', 'SWE', 'CHE',
#        'THA', 'TUR', 'UKR', 'ARE', 'GBR', 'USA', 'URY', 'VEN', 'VNM',
#        'OWID_WRL'], dtype=object)

# %%
df_covid = pd.read_csv('prefect/data/covid_20230316.csv')

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295411 entries, 0 to 295410
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    295411 non-null  object
#  1   continent                                   281395 non-null  object
#  2   location                                    295411 non-null  object
#  3   date                                        295411 non-null  object
#  4   total_cases                                 259937 non-null  float64
#  5   new_cases                                   287174 non-null  float64
#  6   new_cases_smoothed                          285910 non-null  float64
#  7   total_deaths                                239564 non-null  float64
#  8   new_deaths                                  287252 non-null  float64
# ...

# %%
df_covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
len(df_covid.iso_code.unique())
# Out:
# 255
